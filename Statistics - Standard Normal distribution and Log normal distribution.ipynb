# %% [markdown]
# ### Lognormal Distribution

# %% [markdown]
# A random variable X belongs to log normal distribution if ln(x) ~ N(mean,standard deviation)
#
# A lognormal (log-normal or Galton) distribution is a probability distribution with a normally distributed logarithm. A random variable is lognormally distributed if its logarithm is normally distributed.

# %% [markdown]
# Example:
#
# 1. Incomes of people in a country
#
# 2. word count of the product review

# %% [markdown]
# When are Lognormal Distributions Used?
#
# The most commonly used (and the most familiar) distribution in science is the normal distribution. The familiar “bell curve” models many natural phenomenon, from the simple (weights or heights) to the more complex. For example, the following phenomenon can all be modeled with a lognormal distribution:
#
# Milk production by cows.
#
# Lives of industrial units with failure modes that are characterized by fatigue-stress.
#
# Amounts of rainfall.
#
# Size distributions of rainfall droplets.
#
# The volume of gas in a petroleum reserve.

# %% [markdown]
# ![1200px-PDF-log_normal_distributions.svg.png](attachment:1200px-PDF-log_normal_distributions.svg.png)

# %% [markdown]
# ### The Standard Normal Distribution

# %% [markdown]
# The standard normal distribution is a normal distribution with a mean of zero and standard deviation of 1. The standard normal distribution is centered at zero and the degree to which a given measurement deviates from the mean is given by the standard deviation

# %% [markdown]
# Importance of standardization:
#
# Standardization comes into picture when features of input data set have large differences between their ranges, or simply when they are measured in different measurement units (e.g., Pounds, Meters, Miles … etc).
#
# These differences in the ranges of initial features causes trouble to many machine learning models. For example, for the models that are based on distance computation, if one of the features has a broad range of values, the distance will be governed by this particular feature.

# %% [markdown]
# For the standard normal distribution, 68% of the observations lie within 1 standard deviation of the mean; 95% lie within two standard deviation of the mean; and 99.9% lie within 3 standard deviations of the mean

# %% [markdown]
# Since the area under the standard curve = 1, we can begin to more precisely define the probabilities of specific observation. For any given Z-score we can compute the area under the curve to the left of that Z-score.

# %% [markdown]
# The following formula converts an X value into a Z score, also called a standardized score:
#
# ![equation_image110.jpg](attachment:equation_image110.jpg)
#
# where μ is the mean and σ is the standard deviation of the variable X.

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# ![Screenshot%202021-07-09%20193512.png](attachment:Screenshot%202021-07-09%20193512.png)

# %% [markdown]
# P.S : I have collected this information and images from various sources
#
# credits to the creators
