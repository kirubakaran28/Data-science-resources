# %% [markdown]
# ## Spearman's rank correlation coefficient

# %% [markdown]
# Spearman's rank correlation coefficient is a nonparametric measure of rank correlation (statistical dependence between the rankings of two variables). It assesses how well the relationship between two variables can be described using a monotonic function.

# %% [markdown]
# The Spearman correlation between two variables is equal to the Pearson correlation between the rank values of those two variables; while Pearson's correlation assesses linear relationships, Spearman's correlation assesses monotonic relationships (whether linear or not). If there are no repeated data values, a perfect Spearman correlation of +1 or −1 occurs when each of the variables is a perfect monotone function of the other.

# %% [markdown]
# ![Screenshot%202021-07-12%20191019.png](attachment:Screenshot%202021-07-12%20191019.png)

# %% [markdown]
# ![450px-Spearman_fig3.svg.png](attachment:450px-Spearman_fig3.svg.png)

# %% [markdown]
# Even the relation between x and y is linear in the above case due to the outliers pearson correlation is not performing well and spearman correlation was able to identify the correlation properly

# %% [markdown]
# ### example:
#
# ![Screenshot%202021-07-12%20191413.png](attachment:Screenshot%202021-07-12%20191413.png)

# %% [markdown]
# ![Screenshot%202021-07-12%20191519.png](attachment:Screenshot%202021-07-12%20191519.png)

# %% [markdown]
# i have gathered these information from various sources and i dont own any of the above content
# credits to the creators
